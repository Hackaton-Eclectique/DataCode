# %%
import pandas as pd

# %%
lst = ["one", "two", "three", "four", "five"]
new_lst = []
for i in lst:
    df = pd.read_csv(f"/data/{i}.csv")
    new_lst.append(df)

finall = pd.concat(new_lst)

# %%
finall.sample(10)
# Out:
#      Unnamed: 0                                           receipe  \
# 89           89                             Spinach and rice soup
# 61           61                         Tandoori chicken chapatti
# 6             6                             Poached salmon blinis
# 19           19                      Potato, leek and cheese soup
# 60           60  Microwave mug: Chocolate, banana and almond cups
# 57           57                Minced beef and vegetable filo pie
# 67           67                                Marinated monkfish
# 5             5                                      Rhubarb fool
# 103         103                   Ham, leek and Parmesan frittata
# 107         107                                 Green summer soup
#
#                                            nutricional  \
# 89   Each 559g serving contains (excludes serving s...
# 61   Each 210g serving contains (excludes serving s...
# 6    Each 34g serving contains (excludes serving su...
# ...
